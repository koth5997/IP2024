# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('view3.png',0)
img2 = cv2.imread('view5.png',0) # trainImage


sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
matches = matcher.match(des1, des2)

matches = sorted(matches, key = lambda x:x.distance)

# %%
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:40], None, flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1445809d7f0>, None)

# %%
img1 = cv2.imread('dak1.png',0)
img2 = cv2.imread('dak2.png',0) # trainImage


sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
matches = matcher.match(des1, des2)

matches = sorted(matches, key = lambda x:x.distance)

# %%
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:50], None, flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x14458218940>, None)

# %%
img1 = cv2.imread('dak1.png',0)
img2 = cv2.imread('dak2.png',0) # trainImage


sift = cv2.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
matches = matcher.match(des1, des2)

matches = sorted(matches, key = lambda x:x.distance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 17
#      15         good.append([m])
#      16  # cv2.drawMatchesKnn expects list of lists as matches.
# ---> 17 matches = sorted(matches, key = lambda x:x.distance)
#      19 img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:50], None,
#      20                        flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
#      21 plt.imshow(img3),plt.show()
#
# Cell In[73], line 17, in <lambda>(x)
#      15         good.append([m])
#      16  # cv2.drawMatchesKnn expects list of lists as matches.
# ---> 17 matches = sorted(matches, key = lambda x:x.distance)
#      19 img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:50], None,
#      20                        flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
#      21 plt.imshow(img3),plt.show()
#
# ...

# %%
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:50], None, 
                       flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
